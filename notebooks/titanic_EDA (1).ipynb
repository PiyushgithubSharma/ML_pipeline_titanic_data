# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("//content/drive/MyDrive/Synoris_2nd.md/titanic_data_analysis/titanic.csv")

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
new_df = df.copy()

# %%
new_df=new_df.drop(columns=["who","adult_male","embark_town","embarked","alive","alone"],axis=1)

# %%
new_df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare  class deck
# 0         0       3    male  22.0      1      0   7.2500  Third  NaN
# 1         1       1  female  38.0      1      0  71.2833  First    C
# 2         1       3  female  26.0      0      0   7.9250  Third  NaN
# 3         1       1  female  35.0      1      0  53.1000  First    C
# 4         0       3    male  35.0      0      0   8.0500  Third  NaN

# %%
new_df.nunique()
# Out:
# survived      2
# pclass        3
# sex           2
# age          88
# sibsp         7
# parch         7
# fare        248
# class         3
# deck          7
# dtype: int64

# %%
new_df.isnull().sum()
# Out:
# survived      0
# pclass        0
# sex           0
# age         177
# sibsp         0
# parch         0
# fare          0
# class         0
# deck        688
# dtype: int64

# %%
new_df = new_df.drop(["deck"],axis =1)

# %%
new_df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare  class
# 0         0       3    male  22.0      1      0   7.2500  Third
# 1         1       1  female  38.0      1      0  71.2833  First
# 2         1       3  female  26.0      0      0   7.9250  Third
# 3         1       1  female  35.0      1      0  53.1000  First
# 4         0       3    male  35.0      0      0   8.0500  Third

# %%
new_df.nunique()
# Out:
# survived      2
# pclass        3
# sex           2
# age          88
# sibsp         7
# parch         7
# fare        248
# class         3
# dtype: int64

# %%
new_df.isnull().sum()
# Out:
# survived      0
# pclass        0
# sex           0
# age         177
# sibsp         0
# parch         0
# fare          0
# class         0
# dtype: int64

# %%
new_df['age'] = new_df['age'].fillna(new_df['age'].mean())

# %%
new_df.isnull().sum()
# Out:
# survived    0
# pclass      0
# sex         0
# age         0
# sibsp       0
# parch       0
# fare        0
# class       0
# dtype: int64

# %%
new_df['sex'].value_counts()
# Out:
# sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
new_df['sex'] = new_df['sex'].map({'male': 1, 'female': 0})

# %%
new_df.describe()
# Out:
#          survived      pclass         sex         age       sibsp       parch  \
# count  891.000000  891.000000  891.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642    0.647587   29.699118    0.523008    0.381594
# std      0.486592    0.836071    0.477990   13.002015    1.102743    0.806057
# min      0.000000    1.000000    0.000000    0.420000    0.000000    0.000000
# 25%      0.000000    2.000000    0.000000   22.000000    0.000000    0.000000
# 50%      0.000000    3.000000    1.000000   29.699118    0.000000    0.000000
# 75%      1.000000    3.000000    1.000000   35.000000    1.000000    0.000000
# max      1.000000    3.000000    1.000000   80.000000    8.000000    6.000000
#
#              fare
# count  891.000000
# mean    32.204208
# std     49.693429
# min      0.000000
# 25%      7.910400
# 50%     14.454200
# 75%     31.000000
# max    512.329200

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   survived  891 non-null    int64
#  1   pclass    891 non-null    int64
#  2   sex       891 non-null    int64
#  3   age       891 non-null    float64
#  4   sibsp     891 non-null    int64
#  5   parch     891 non-null    int64
#  6   fare      891 non-null    float64
#  7   class     891 non-null    object
# dtypes: float64(2), int64(5), object(1)
# memory usage: 55.8+ KB

# %%
new_df['class'].value_counts()
# Out:
# class
# Third     491
# First     216
# Second    184
# Name: count, dtype: int64

# %%
new_df['class'] = new_df['class'].map({'First':1,'Second':2,'Third':3})

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   survived  891 non-null    int64
#  1   pclass    891 non-null    int64
#  2   sex       891 non-null    int64
#  3   age       891 non-null    float64
#  4   sibsp     891 non-null    int64
#  5   parch     891 non-null    int64
#  6   fare      891 non-null    float64
#  7   class     891 non-null    int64
# dtypes: float64(2), int64(6)
# memory usage: 55.8 KB

# %%
new_df.to_csv('titanic_clean_data.csv', index=False)

# %%
new_df.corr()
# Out:
#           survived    pclass       sex       age     sibsp     parch  \
# survived  1.000000 -0.338481 -0.543351 -0.069809 -0.035322  0.081629
# pclass   -0.338481  1.000000  0.131900 -0.331339  0.083081  0.018443
# sex      -0.543351  0.131900  1.000000  0.084153 -0.114631 -0.245489
# age      -0.069809 -0.331339  0.084153  1.000000 -0.232625 -0.179191
# sibsp    -0.035322  0.083081 -0.114631 -0.232625  1.000000  0.414838
# parch     0.081629  0.018443 -0.245489 -0.179191  0.414838  1.000000
# fare      0.257307 -0.549500 -0.182333  0.091566  0.159651  0.216225
# class    -0.338481  1.000000  0.131900 -0.331339  0.083081  0.018443
#
#               fare     class
# survived  0.257307 -0.338481
# pclass   -0.549500  1.000000
# sex      -0.182333  0.131900
# age       0.091566 -0.331339
# sibsp     0.159651  0.083081
# parch     0.216225  0.018443
# fare      1.000000 -0.549500
# class    -0.549500  1.000000

# %%
new_df = new_df.drop(['class'],axis =1)

# %%
new_df
# Out:
#      survived  pclass  sex        age  sibsp  parch     fare
# 0           0       3    1  22.000000      1      0   7.2500
# 1           1       1    0  38.000000      1      0  71.2833
# 2           1       3    0  26.000000      0      0   7.9250
# 3           1       1    0  35.000000      1      0  53.1000
# 4           0       3    1  35.000000      0      0   8.0500
# ..        ...     ...  ...        ...    ...    ...      ...
# 886         0       2    1  27.000000      0      0  13.0000
# 887         1       1    0  19.000000      0      0  30.0000
# 888         0       3    0  29.699118      1      2  23.4500
# 889         1       1    1  26.000000      0      0  30.0000
# 890         0       3    1  32.000000      0      0   7.7500
#
# [891 rows x 7 columns]

# %%
sns.heatmap(new_df.corr(),annot=True)
# Out:
# <Axes: >

# %%
new_df.plot(x="survived", y="pclass", kind="bar")
plt.ylabel("Values");
plt.show()

# %%
sns.barplot(data=new_df,x='survived',y='pclass')
# Out:
# <Axes: xlabel='survived', ylabel='pclass'>

# %%
sns.barplot(data=new_df,x='survived',y='fare')
# Out:
# <Axes: xlabel='survived', ylabel='fare'>
